# %% [markdown]
# ## Yolov5(Ultraytics)
# (참조) https://github.com/ultralytics/yolov5/blob/master/tutorial.ipynb

# %% [markdown]
# # Setup
#
# Clone GitHub [repository](https://github.com/ultralytics/yolov5), install [dependencies](https://github.com/ultralytics/yolov5/blob/master/requirements.txt) and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16094, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 16094 (delta 0), reused 4 (delta 0), pack-reused 16089
# Receiving objects: 100% (16094/16094), 14.76 MiB | 14.31 MiB/s, done.
# Resolving deltas: 100% (11024/11024), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
pwd
# Out:
# '/content/yolov5'

# %%
# !pip install -U pillow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 18.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.1.0 which is incompatible.
# ...

# %%
# %pip install -qr requirements.txt  # install
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.5/660.5 kB 16.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.1 MB/s eta 0:00:00

# %%
import torch
import utils

# %%
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-249-gf400bba Python-3.10.12 torch-2.1.0+cu121 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/107.7 GB disk)

# %%
display
# Out:
# <module 'IPython.display' from '/usr/local/lib/python3.10/dist-packages/IPython/display.py'>

# %% [markdown]
# # 1. Detect
#
# `detect.py` runs  inference on a variety of sources, downloading models automatically from the [latest  release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`.

# %%
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)

# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images
# Out:
# detect: weights=['yolov5s.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-249-gf400bba Python-3.10.12 torch-2.1.0+cu121 CPU
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 191MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/2 /content/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 bus, 238.2ms
# image 2/2 /content/yolov5/data/images/zidane.jpg: 384x640 2 persons, 2 ties, 175.7ms
# Speed: 1.2ms pre-process, 207.0ms inference, 14.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
pwd
# Out:
# '/content/yolov5'

# %%
# colab에서 mp4를 올리고 아래 명령어를 실행하면 학습하고 그결과가 runs/detect아래 쌓인
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source test.mp4
# Out:
# detect: weights=['yolov5s.pt'], source=test.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-249-gf400bba Python-3.10.12 torch-2.1.0+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# video 1/1 (1/302) /content/yolov5/test.mp4: 384x640 17 persons, 2 bicycles, 1 motorcycle, 1 bench, 222.8ms
# video 1/1 (2/302) /content/yolov5/test.mp4: 384x640 16 persons, 3 bicycles, 1 motorcycle, 1 bench, 1 handbag, 190.2ms
# video 1/1 (3/302) /content/yolov5/test.mp4: 384x640 16 persons, 3 bicycles, 1 motorcycle, 1 bench, 1 handbag, 180.0ms
# ...
