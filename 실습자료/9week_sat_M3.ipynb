# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import korean_language
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# #### 손실함수 : 모델의 예측값과 실젝값의 오차
# ##### - 분류 : 크로스엔트로피
# ##### - 회귀 : MSE, MAE
# #### 하이퍼 파라미터 : 모델의 동작을 규정
# #### 파라미터 : 모델이 잘 작동하도록 학습하는 매개변수(가중치)
# #### 경사하강법 : 예측값이 실제값에 수렴하도록 가중치를 갱신
# #### 훈련 : 모델이 데이터를 이용해 모델 파라미터를 학습하는과정
# #### 검증 : 모델 학습 중에 과소/과대적합을 검사하고 최적 모델 구조를 찾는데 사용-모델이 잘 작동되는지 확인하는 과정
# #### 테스트 모델의 성능 최종적으로 시험하는데 사용
# #### 일반화 : 과대적합을 피해서 일반적으로 성능이 적절히 나오게 하는것이 좋은 모델 - 즉, 훈련과 테스트결과 비슷하게 나오게 하는것 -> 일반화 능력을 갖도록 모델을 규제화
# #### 과대적합 원인 : 데이터가 적거나 모델이 너무 복잡한 경우 - 파라미터를 줄임
# ![image.png](attachment:7bee53fe-5a82-426a-875b-9b21eb7f8219.png)
# ---
