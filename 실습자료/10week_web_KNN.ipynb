# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import korean_language
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### 최적화방법(학습방법, optimazation method)
# #### - 경사하강법
# ---
# ### 모델학습절차
# ![image.png](attachment:74e3670a-476a-4bab-8386-b47ca09e54a0.png)
# ---
# ### 강의 밴드 사이트 https://band.us/band/92125841
# ---
# ### 분류최적화
# ![image.png](attachment:cd8bed1b-b33e-4989-923f-8ecbc91473fc.png)
#
# ### 배치 : 데이터학습하고 손실함수를 통해 최적화를 할 때 사용하는 샘플수 - 예) 100개 샘플단위로 학습하여 오차를 갱신, 즉 한번 학습에 사용되는 샘플수
# ### 이포크 : 학습할 전체 데이터
# ---
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
#help(iris)
x, y = iris.data, iris.target

# %%
train_x, test_x,train_y, test_y = train_test_split(x,y, test_size=0.3)
train_x.shape, test_x.shape, train_y.shape, test_y.shape
# Out:
# ((105, 4), (45, 4), (105,), (45,))

# %%
sgd = SGDClassifier()
knn = KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(train_x, train_y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
print('knn score : {:.2f}'.format(knn.score(test_x, test_y)))
# Out:
# knn score : 0.96

# %%
sgd.fit(train_x, train_y)
# Out:
# SGDClassifier()

# %%
print('sgd score : {:.2f}'.format(sgd.score(test_x, test_y)))
# Out:
# sgd score : 0.84

# %%
for i in range(1,10):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(train_x,train_y)
    print('K가 {}개일때 knn score : {:.4f}'.format(i, knn.score(test_x, test_y)))
# Out:
# K가 1개일때 knn score : 0.9333
# K가 2개일때 knn score : 0.9556
# K가 3개일때 knn score : 0.9333
# K가 4개일때 knn score : 0.9333
# K가 5개일때 knn score : 0.9556
# K가 6개일때 knn score : 0.9333
# K가 7개일때 knn score : 0.9333
# K가 8개일때 knn score : 0.9333
# K가 9개일때 knn score : 0.9333

# %%
train_x[0:3]
# Out:
# array([[6. , 2.7, 5.1, 1.6],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.8, 3. , 5.5, 2.1]])

# %%
knn.predict([[0.2, 1.8, 5.1, 5.4]])
# Out:
# array([1])

# %%
np.shape([[0.2, 1.8, 5.1, 5.4]])
# Out:
# (1, 4)

# %%
np.shape([0.2, 1.8, 5.1, 5.4])
# Out:
# (4,)

# %% [markdown]
# ### 거리가 가까운 데이터에 가중치를 크게 적용해 분류성능을 조절할수도 있다
# ---

# %% [markdown]
# # Decision Tree
# ![image.png](attachment:7e564dad-18fb-4d22-83a0-2f0a3b04c848.png)
